# %% [markdown]
# <!-- Cache bust 98e6910f-4e81-4f78-a367-238cf8ef0019 -->

# %% [markdown]
# # Data Structures

# %% [markdown]
# ### In-build data structures

# %% [markdown]
# * Data structures are used to store, organize, and manipulate
# data efficiently. Python provides several built-in data
# structures
# * And for storing multiple values we will again use variables
# * Now in python we have 4 types of in-build data structure
# List, Tuple, Dictionary, Set.

# %% [markdown]
# ### Custom data structures

# %% [markdown]
# * Now there are some custom data structures as well like
# Stack, Queue, Linked List, Graph etc.
# * And around these data structures there are some algorithms
# like searching algorithms, sorting algorithms.
# * And this is why the study is called data structures and
# algorithm

# %% [markdown]
# ***

# %% [markdown]
# ## List Powers

# %% [markdown]
# * **Mutable ->**  Mutability refers to whether an object's value
# can be changed after creation. And List allows this
# * **Duplicates ->**  we know data structures are used to store
# multiple values so duplicates means same value occuring
# multiple time. List allows this
# * **Ordered ->**   List maintains ordered data structure maintains
# the sequence of elements as they were inserted. This
# means you can access elements using their position
# (index)
# * **Heterogenous ->**   List have heterogenous nature that means
# we can have multiple data types inside the list.

# %% [markdown]
# ## List Basics

# %% [markdown]
# First we have to know what is the syntax of list and how, to
# create a list we have to use square brackets [ ]

# %%
a = [10, 20, 30]

# %% [raw]
# a ──► [ addr1 | addr2 | addr3 ]
#         │       │       │
#        10      20      30

# %% [markdown]
# ##### Important consequences:
#
# * List stores addresses, not values
# * Elements can be different types
# * Changing element modifies same object (mutability)

# %%
numbers= [2,44,67,22,00,23.5,22.88]
print(numbers)
print(numbers[1])

# %%
names=["Kamran",'Chetan','ARBAZ',"ArHam"]
print(names)

# %%
list=["KK",34,66.6,30,77.0,True,print()]
print(list)

# %% [markdown]
# *  List has Indexing and slicing and it is same as string
# *  The changes we saw in string and list is about mutability, we
# can’t change the values of string. but we can of list.

# %%
numbers[1]=99
print(numbers)

# %% [markdown]
# ### Copy vs Reference

# %%
b = a      # same object
b = a[:]   # shallow copy
b = list(a)

# %% [markdown]
# ***

# %% [markdown]
# ## LIST CREATION

# %% [markdown]
# ###  1. Direct creation

# %%
l=[3,5,77,8]

# %% [markdown]
# ### 2. Empty list

# %%
a = []
a = list()

# %% [markdown]
# ### 3. Using range

# %%
a = list(range(5))

# %% [markdown]
# ### 4. From input

# %%
nums = list(map(int,input().split()))

# %% [markdown]
# ### 5. List comprehension

# %%
squares = [x*x for x in range(5)]    # This is Pythonic and faster.

# %% [markdown]
# ### Nested list

# %%
matrix = [[0]*3 for _ in range(3)]

# %% [markdown]
# Important: not [[0]*3]*3 (shared rows bug)

# %% [markdown]
# ***

# %% [markdown]
# ## INDEXING & SLICING

# %%
a=[44,5,32,10,56,89,70]

# %% [markdown]
# #### #Forward indexing

# %%
print(a[0])          # a[0] = 44  
print(a[2])          # a[2] = 32

# %% [markdown]
# #### #Backward indexing

# %%
print(a[-1])          # a[-1] = 89  
print(a[-3])          # a[-3] = 10

# %% [markdown]
# #### #Slicing
#
# General form:

# %%
a[start : stop : step]

# %%
print(a[1:4])
print(a[:3])
print(a[::2])
print(a[::-1])

# %% [markdown]
# #### #Important behavior — slicing copies

# %%
b= a[1:4]

# %% [markdown]
# Creates new list → safe
#
# But:

# %%
b = a

# %% [markdown]
# No copy → shared

# %% [markdown]
# ***

# %% [markdown]
# ## List Traversing and methods

# %% [markdown]
# *  List traversing is also similar to string traversing it can
# be looped using the index values and directly
# * List has some methods that are used to do many.

# %%
#1st way using index 
for i in range (len(numbers)): 
    print(i)          #To print only index

# %%
for i in range (len(list)): 
    print(list[i])       # print index values

# %%
#2nd way Directly on values 
for a in names: 
    print(a)

# %% [markdown]
# ## LIST METHODS

# %%
n=[45,99,100,345.5,12,66.6,True,"kk","cat",67,"Bat"]

# %% [markdown]
# ### append()
#
# Add element at end

# %%
n.append(90)
print(n)

# %% [markdown]
# ### extend()
#
# Add multiple elements

# %%
n.extend([30,3,"Dog"])
print(n)

# %% [markdown]
# ### insert(index,value)
#
# Shift elements right

# %%
n.insert(0,50)
print(n)

# %% [markdown]
# ### remove(value)
#
# Deletes first occurrence

# %%
n.remove("cat")
print(n)

# %% [markdown]
# ### pop(index)
#
# Removes & returns

# %%
n.pop()    #last
n.pop(3)   #index
print(n)

# %% [markdown]
# ### sort()
#
# In-place sorting

# %%
m=[44,35,66,7.8,100,66,66]
m.sort()
print(m)

# %% [markdown]
# ### reverse()
#
# Reverse in-place

# %%
n.reverse()
print(n)

# %%
m.reverse()
print(m)

# %% [markdown]
# ### clear()
#
# Delete all elements

# %%
l1=[40,66,71,101,50,66,66,7]

# %%
l1.clear()
print(l1)

# %% [markdown]
# ### count()
#
# Count occurance of any numbers/str

# %%
count_m = m.count(66)
print(count_m)

# %% [markdown]
# ### index()
#
# Find index of any number

# %%
index_m =m.index(7.8)
print(index_m)

# %% [markdown]
# ### copy()
#
# Create a copy of the list

# %%
new_list= m.copy()
print(new_list)

# %% [markdown]
# ***

# %% [markdown]
# ## LIST vs ARRAY

# %% [markdown]
# | Feature     | Python List         | Array (NumPy/C)     |
# | ----------- | ------------------- | ------------------- |
# | Type        | mixed               | single type         |
# | Memory      | references          | contiguous          |
# | Speed       | slower              | faster              |
# | Flexibility | high                | low                 |
# | Usage       | general programming | numerical computing |

# %% [markdown]
# #### ML uses:
#
# **list → numpy array → tensor**

# %% [markdown]
# ### DATA PREPROCESSING USAGE

# %% [markdown]
# Before model training:
#
# Raw text dataset
#
# "23,45,12,67"
#
# Steps

# %%
data = input().split(",")
nums = [int(x) for x in data]
clean = [x for x in nums if x>20]

# %% [markdown]
# #### Lists are used for:
#
# * cleaning
# * filtering
# * feature building
# * batching

# %% [markdown]
# ### 🧠 COMMON LIST BUGS

# %% [markdown]
# #### Bug 1 — shared nested list

# %%
grid = [[0]*3]*3
grid[0][0]=1

# %% [markdown]
# All rows change.

# %% [markdown]
# #### Bug 2 — removing while iterating

# %%
for x in a:
    if x%2==0:
        a.remove(x)

# %% [markdown]
# skips elements

# %% [markdown]
# #### Bug 3 — modifying copy confusion

# %%
b=a[:]
b[0]=100

# %% [markdown]
# a unchanged

# %% [markdown]
# ***

# %%
#Q Print positive and negative elements of an List
list_1=[33,-3,556,79,10,-44,-75,50,33,-46]
for i in list_1: 
    if i>=0: 
        print(f"{i} is Positive no")
    else:
        print(f" {i} is Negative no")

# %%
#Q Mean of List elements
l=[56,70,23,666,1]
sum=0 
for i in l:
    sum =sum + i 
print(f" mean is {sum/len(l)}")

# %%
#Q Find the greatest element and print its index too
l2=[45,75,12,666,90]
largest =l2[0]
index=0
for i in range(len(l)):
    if l2[i]>largest: 
        largest = l2[i]
        index=i
print(f"Largest no is {largest} of index {index}")

# %%
#Q Find the second greatest element
l3=[45,75,12,666,90,600,700]
largest =l2[0]
sec_largest =l3[0]
for i in l3:
    if i> largest: 
        sec_largest= largest 
        largest= i 
    elif i>sec_largest: 
        sec_largest = i 
print(f"second largest value is {sec_largest} and largest value is {largest}")

# %%
#Q Check if List is sorted or not.
a=[2,4,10,2,30]
for i in range(len(a)-1):
    if a[i] < a[i + 1]:
        continue
    else :
        print("Your list is not sorted")
        break
else: 
    print("Your list is sorted")

# %% [markdown]
# ***

# %% [markdown]
# ## Tuple

# %% [markdown]
# #### What is a Tuple?
#
# A tuple is:
# * An ordered, immutable collection of elements.
#
# Example:

# %%
tup=(3,5,66,78)

# %% [markdown]
# ### Tuple Powers

# %% [markdown]
# * **Mutable ->**  Tuples are not mutable you cannot change
# the values of tuple
# * **Duplicates ->**  You can have duplicate values in tuple there
# are no restriction
# * **Ordered ->**   Set are ordered and you can access them
# through index values
# * **Heterogenous ->**   Set also have heterogenous nature and
# can have different types of data structure in tuple.

# %% [markdown]
# #### Why Tuples Exist?
#
# If lists already exist, why tuples?
#
# Because:
#
# * Safer (no accidental modification)
# * Faster than lists
# * Hashable (can be dictionary keys)
# * Memory Model
#
# List:

# %%
mutable → dynamic array → slower

# %% [markdown]
# Tuple:

# %%
fixed → compact → slightly faster

# %% [markdown]
# #### Creating Tuples

# %%
t = (1,2,3)
t = 1,2,3
t = tuple([1,2,3])

# %% [markdown]
# Single element tuple:

# %%
t = (5,)   # comma required

# %% [markdown]
# ***

# %% [markdown]
# ### Tuple Traversing and methods

# %% [markdown]
# * Tuples are traversed in the same manner as List are
# traversed
# * But tuples are like strings you can’t change
# anything once it’s made we can’t change them.
# * There are only 2 methods of tuple one for finding the
# index and other of counting the occurrences of an element.

# %% [markdown]
# #### Tuple Indexing & Slicing
#
# Same as list:

# %%
t = (10,20,30,40)

t[0]      → 10
t[-1]     → 40
t[1:3]    → (20,30)

# %% [markdown]
# Immutability Example

# %%
t = (1,2,3)
t[0] = 10   # ❌ Error

# %% [markdown]
# Because object is fixed.

# %%
t = ([1,2], 3)
t[0][0] = 100
print(t)

# %% [markdown]
# Why allowed?
#
# * Because tuple is immutable,
# but inner list is mutable.
# * Tuple protects structure, not nested objects.

# %% [markdown]
# Tuple as Dictionary Key

# %%
d = {(1,2): "point"}

# %% [markdown]
# * Works because tuple is hashable.
# * List cannot be dictionary key.

# %%
t=(34,2,60,15,55,78,10,15)         #initial tuple

# %% [markdown]
# ### index()

# %%
index= t.index(2)
print(index)            #find the index of the first occurance of 2

# %%
count_15 = t.count(15)
print(count_15)

# %% [markdown]
# #### There are only 2 methods of tuple one for finding the index and other of counting the occurrences of an element.

# %% [markdown]
# ***

# %% [markdown]
# ## Set

# %% [markdown]
# ##### What is a Set?
#
# A set is:
# * An unordered collection of unique elements.

# %%
s={3,45,7} 
print(s)
print(type(s))

# %% [markdown]
# ##### Important:
#
# * No duplicates
# * No indexing
# * No order guarantee

# %% [markdown]
# ***

# %% [markdown]
# ### Set Powers

# %% [markdown]
# * **Mutable ->**  Sets are mutable you can change the values of
# set
# * **Duplicates ->**  You cannot have any duplicate values in se
# that means every element will be unique
# * **UnOrdered ->**    Sets are unordered and you cannot access
# them through index values
# * **Heterogenous ->**    Set is semi-heterogenous it can store
# some data types like string, numbers, tuples but not
# everything

# %% [markdown]
# ### Internally How Sets Work
#
# * Sets use hash tables.
#
# Meaning:
#
# * Fast lookup
# * O(1) average time complexity
#
# ### Creating Sets

# %%
s = {1,2,3}
s = set([1,2,3])

#empty set
s = set()     # correct
s = {}        # dictionary, not set

# %% [markdown]
# #### How Set stores value in python
#
# * Each value in a set is hashed using a hash function (hash() in
# Python)
# * The hash is used as an index to store the element in memory
# * Since hashing does not maintain order, sets are unordered
# * Only immutable (hashable) objects can be stored in a set
# (e.g., numbers, strings, tuples). Mutable objects like lists and
# dictionaries are not allowed
# * See the video for more clear understanding

# %% [markdown]
# ***

# %% [markdown]
# ### Set Properties

# %% [markdown]
# Duplicates automatically removed:

# %%
s = {1,2,2,3}
print(s)

# %% [markdown]
# Order not guaranteed.

# %% [markdown]
# ### Set Traversing

# %% [markdown]
# * A set cannot be traversed using the index values cause it is
# unordered and has no index
# * So many times it will give random values.

# %% [markdown]
# ***

# %% [markdown]
# ### Set Operations

# %% [markdown]
# * set methods are very powerful cause you don’t have
# any indexing you cannot change the values but set is
# mutable so we use methods for this
# * For adding and removing the elements you can use methods
# as follows :

# %%
s={23,45,55,2,19,900,600,23,55,23,11,5}

# %% [markdown]
# * #### add()
#
# Add element

# %%
s.add(95)
print(s)

# %% [markdown]
# * #### remove()
#
# Remove element

# %%
s.remove(900)
print(s)

# %% [markdown]
# * #### Discard (safe remove)

# %%
s.discard(600)   # no error
print(s)

# %% [markdown]
# * These are some of the basic methods but sets also have
# some special methods for performing some special
# operations between 2 sets.

# %%
A={1,2,3}
B={3,4,5}

# %% [markdown]
# #### Union

# %%
A | B

# %%
union_set =A.union(B)
print(union_set)

# %% [markdown]
# #### Intersection

# %%
 A & B

# %%
intersection_set= A.intersection(B)
print(intersection_set)

# %% [markdown]
# #### Difference

# %%
A - B

# %%
difference_set = A.difference(B)
print(difference_set)

# %% [markdown]
# #### Symmetric difference

# %%
A ^ B

# %%
symmetric_difference_set = A.symmetric_difference(B)
print(symmetric_difference_set)

# %% [markdown]
# * These are some other operations
# of sets that can be performed
# between 2 sets. And we also have
# shortcuts for them

# %% [markdown]
# ***

# %% [markdown]
# ## Tuple vs List vs Set

# %% [markdown]
# | Feature    | List | Tuple | Set |
# | ---------- | ---- | ----- | --- |
# | Ordered    | ✔    | ✔     | ❌   |
# | Mutable    | ✔    | ❌     | ✔   |
# | Duplicates | ✔    | ✔     | ❌   |
# | Indexing   | ✔    | ✔     | ❌   |
# | Hashable   | ❌    | ✔     | ❌   |

# %% [markdown]
# ***

# %% [markdown]
# ## DATA SCIENCE USAGE

# %% [markdown]
# #### Tuples used for:
#
# * Coordinates (x,y)
# * Immutable records
# * Dictionary keys
# * Returning multiple values
#
# Example:

# %% [raw]
# return loss, accuracy

# %% [markdown]
# #### Sets used for:
#
# * Removing duplicates
# * Fast membership checking
# * Feature filtering
# * Vocabulary building in NLP
#
# Example:

# %% [raw]
# unique_words = set(text.split())

# %% [markdown]
# ***

# %% [markdown]
# ## Dictionary

# %% [markdown]
# ##### What is a Dictionary?
#
# A dictionary is:
#
# An unordered collection of key–value pairs.
#
# Example:

# %%
student = {
    "name": "Kamran",
    "age": 22,
    "branch": "CSE"
}
print(student)

# %% [markdown]
# **Key      → Value**
#
# name     → Kamran
#
# age      → 22
#
# branch   → CSE

# %% [markdown]
# Keys must be unique.

# %% [markdown]
# ***

# %% [markdown]
# #### How Dictionaries Work Internally
#
# Dictionaries use hash tables.
#
# Meaning:

# %% [raw]
# Key → Hash Function → Memory Index → Value

# %% [markdown]
# Example:

# %% [raw]
# "name" → hash() → index → "Kamran"

# %% [markdown]
# This allows:

# %% [raw]
# Lookup time ≈ O(1)

# %% [markdown]
# Much faster than lists.

# %% [markdown]
# ***

# %% [markdown]
# ### Dictionary Powers

# %% [markdown]
# * **Mutable ->**   Dictionaries are mutable, meaning you can
# change, add, or remove key-value pairs after creation
# * **Duplicates ->**  Keys must be unique, but you can have
# duplicates in values
# * **Ordered ->**   Dictionary follows insertion order
# * **Heterogenous ->**   A dictionary can store different types of
# keys and values, like integers, strings, lists, or even
# another dictionary

# %% [markdown]
# ### Creating Dictionaries
#
# ##### Method 1

# %%
d = {"a":1, "b":2} 
print(d)

# %% [markdown]
# ##### Method 2

# %%
dic = dict(a=45, b=66) 
print(dic)

# %% [markdown]
# ##### Method 3

# %%
pairs = [("a",56),("b",20)]
d = dict(pairs)
print(d)

# %% [markdown]
# ##### Empty dictionary

# %%
b = {} 
print(b)

# %% [markdown]
# ***

# %% [markdown]
# ## Dictionary traversing

# %% [markdown]
# * We can traverse both keys and values in dictionary, but
# default loop is set on keys and you can access the values
# because of keys.
# * So technically we can traverse on both keys and values at
# the same time

# %% [markdown]
# ## Accessing Values

# %% [markdown]
# * ### Accessing Values

# %%
d = {"name":"AI","year":2025}

print(d["name"])

# %% [markdown]
# * ### Using get()

# %%
print(d.get("name"))    #Safer because it avoids error.

# %% [markdown]
# * ### Key not found

# %%
print(d.get("salary"))

# %%
d.get("salary",0)     #Default value.

# %% [markdown]
# ## Adding / Updating Values

# %%
d["age"] = 25
print(d)

# %% [markdown]
# If key exists → update
#
# If key not exists → create

# %%
d = {"a":1}

d["a"] = 10
d["b"] = 20

print(d)

# %% [markdown]
# ## Removing Items

# %% [markdown]
# * ### pop()

# %%
d.pop("a")   #Removes key

# %% [markdown]
# * ### del()

# %%
del d["b"]

# %%
print(d)

# %% [markdown]
# * ### popitem()

# %% [raw]
# d.popitem()

# %% [markdown]
# Removes last inserted pair.

# %% [markdown]
# * ### clear()

# %% [raw]
# d.clear()

# %% [markdown]
# Deletes all entries.

# %% [markdown]
# ## Important Dictionary Methods

# %%
d={"Name" : "Kamran" , "Roll no:": 97 ,"City" : "Bokaro"}

# %% [markdown]
# * ### keys()

# %%
d.keys()

# %% [markdown]
# Returns all keys

# %% [markdown]
# * ### values()

# %%
d.values()

# %% [markdown]
# Returns values

# %% [markdown]
# * ### items()

# %%
d.items()

# %% [markdown]
# Returns key–value pairs.

# %%
for k,v in d.items():
    print(k,v)

# %% [markdown]
# * ### update()

# %%
d.update({"c":3})
print(d)

# %% [markdown]
# Merge dictionaries.

# %% [markdown]
# * ### setdefault()

# %%
d.setdefault("x",0)
print(d)

# %% [markdown]
# * Adds key if not present.
# * Very useful in grouping problems.

# %% [markdown]
# ***

# %% [markdown]
# ## Dictionary Comprehension

# %% [markdown]
# Just like list comprehension.

# %%
squares = {x: x*x for x in range(5)}
print(squares)

# %%
even = {x:x*x for x in range(10) if x%2==0}
print(even)

# %% [markdown]
# ## Nested Dictionaries

# %%
students = {
    "s1": {"name":"Ali", "age":20},
    "s2": {"name":"Sara", "age":21}
}
print(students)

# %%
students["s1"]["name"]  #access

# %% [markdown]
# Used heavily in JSON data.

# %% [markdown]
# ***

# %% [markdown]
# ## 📊 Real Data Science Usage

# %%
text = "ai ml ai data"

freq = {}

for word in text.split():
    freq[word] = freq.get(word,0) + 1

print(freq)

# %% [markdown]
# This pattern appears everywhere in NLP.

# %% [markdown]
# ### collections module
#
# Used heavily in ML

# %% [markdown]
# ### Important Dictionary Extensions

# %% [markdown]
# * #### counter()

# %%
from collections import Counter

Counter("banana")

# %% [markdown]
# * #### defaultdict()

# %%
from collections import defaultdict

d = defaultdict(list)

d["a"].append(1)
print(d)

# %% [markdown]
# Automatically creates key.
#
# #### OrderedDict (less used now)
#
# Maintains insertion order.

# %% [markdown]
# ***

# %% [markdown]
# ## 📝 Practice Questions

# %% [markdown]
# ### 🟢 Easy Level

# %%
#Q1 Write a program to sum all elements in a numeric list.

# %%
#Q2 Write a program to append, insert, and pop elements from a list.

# %%
#Q3 Write a program to find the minimum and maximum value in a list without using built-in min/max.

# %%
#Q4 Write a program to merge two dictionaries.

# %%
#Q5 Write a program to check if a key exists in a dictionary.

# %%
#Q6 Write a program to perform set union, intersection, and difference operations.

# %%
#Q7 Write a program to count occurrences of a specific item in a tuple.

# %%
#Q8 Write a program to create a dictionary of squares (1 to 5) using dictionary comprehension.

# %%
#Q9 Write a program to filter out odd numbers from a list using list comprehension.

# %%
#Q10 Write a program to clear all elements from a set.

# %%
#Q11 Write a program to unpack a tuple into individual variables.

# %%
#Q12 Write a program to check if a list is empty.

# %% [markdown]
# ### 🟡 Medium Level

# %%
#Q13 Write a program to remove duplicate values from a list while preserving the original order.

# %%
#Q14 Write a program to sort a dictionary by its values in ascending order.

# %%
#Q15 Write a program to find common elements across three lists using sets.

# %%
#Q16 Write a program to group a list of words by their starting character into a dictionary.

# %%
#Q17 Write a program to rotate a list to the right by K steps.

# %%
#Q18 Write a program to check if set A is a subset or superset of set B.

# %%
#Q19 Write a program to flatten a list of lists of depth 1 using a list comprehension.

# %%
#Q20 Write a program to combine two dictionaries by adding values for common keys.

# %%
#Q21 Write a program to swap keys and values in a dictionary.

# %%
#Q22 Write a program to reverse a list in-place without using the reverse() method or slicing.

# %% [markdown]
# ### 🔴 Hard Level

# %%
#Q23 Write a program to calculate matrix transpose using nested list comprehension.

# %%
#Q24 Write a program to compute Jaccard similarity between two lists of items using sets.

# %%
#Q25 Write a program to implement a deep recursive dictionary update (merge nested dicts).

# %%
#Q26 Write a program to implement a Stack (LIFO) class using list.

# %%
#Q27 Write a program to implement a Queue (FIFO) using collections.deque.

# %%
#Q28 Write a program to retrieve a nested value in a dict using a dot-separated string path.

# %%
#Q29 Write a program to count element frequencies in a deeply nested list structure.

# %%
#Q30 Write a program to find the first non-repeating element in a list in O(N) time.
