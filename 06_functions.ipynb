# %% [markdown]
# <!-- Cache bust 9db3689d-5d18-43cf-a6b1-b8b7f3e932a9 -->

# %% [markdown]
# # Functions

# %% [markdown]
# ### What is a function?
#
# * A reusable named block of logic that transforms input → output.
# * Functions in Python group reusable code into a block that
# can be executed by calling the function name. This helps
# avoid repetition and makes programs modular and readable
# * There are many in-build functions in python like print(), input()
# len() etc
# * But we can create our own function and they are called as
# user defined functions. To make your own function we have
# to use def keyword and then name the function. After this
# we have to call the function using name() and paranthesis

# %% [markdown]
# ##### Very important mental model:
#
# data → function → new data
#
# ##### This is EXACTLY how ML works:
#
# raw data → preprocessing → features → model → predictions

# %% [markdown]
# ***

# %% [markdown]
# ### DEFINING FUNCTIONS

# %%
def hello():
    print("this is a hello function so I am doing hello")

# %%
hello()
# Out:
# this is a hello function so I am doing hello

# %%
def add_numbers():
    print(2+3)

# %% [markdown]
# What happens internally?
#
# Python does NOT run the code immediately.
#
# It stores a recipe in memory.
#
# ##### Only when called:

# %%
add_numbers()
# Out:
# 5

# %% [markdown]
# Then execution happens.

# %% [markdown]
# ### Execution Flow

# %%
def greet():
    print("Hello")

print("Start")
greet()
print("End")
# Out:
# Start
# Hello
# End

# %% [markdown]
# Function body runs only when called.

# %% [markdown]
# ***

# %% [markdown]
# ### PARAMETERS vs ARGUMENTS

# %% [markdown]
# #### Parameters (placeholders)

# %% [markdown]
# * Parameters are variables listed inside the function definition.
# * For making the function we have to accept inside the
# parenthesis of the function.

# %%
def add(a, b):
    print(a + b)

# %% [markdown]
# a and b are parameters — empty variables waiting for values.

# %%
def hello(name,age):             #name & age are Parameters
    print(f"your name is {name} and your age is {age}")

# %% [markdown]
# #### Arguments (actual values)

# %% [markdown]
# Arguments are the Values passed to a function when it is called

# %%
hello("Kamran",22)       #Kamran & 22 are Arguments
# Out:
# your name is Kamran and your age is 22

# %%
add(5, 3)
# Out:
# 8

# %% [markdown]
# 5 and 3 are arguments — real data.

# %% [markdown]
# #### Visual model

# %% [markdown]
# function add(a,b)
#             ↑ ↑
# arguments → 5 3

# %% [markdown]
# Python creates new local variables:

# %%
a = 5
b = 3

# %% [markdown]
# ***

# %% [markdown]
# ### Types of arguments

# %% [markdown]
# #### Positional arguments

# %% [markdown]
# Order matters

# %% [markdown]
# First parameter, will always capture first
# argument and so on. These arguments are called
# argument Positional arguments

# %% [markdown]
# **First Example**

# %%
def add(a,b): 
    return a+b
print(add(3,5))        #3 is assigned to 'a' & 5 is assigned to 'b'
# Out:
# 8

# %%
def subtract(a,b):
    print(a-b)

subtract(10,5)  # 5              #10 is assigned to 'a' & 5 is assigned to 'b'
subtract(5,10)  # -5             #5 is assigned to 'a' & 10 is assigned to 'b'
# Out:
# 5
# -5

# %% [markdown]
# * First example shows how positional arguments work

# %% [markdown]
# #### Keyword arguments

# %% [markdown]
# Order does NOT matter

# %%
subtract(b=5, a=10)
# Out:
# 5

# %% [markdown]
# **Second Example**

# %%
def hello(name,age):             #name & age are Parameters
    print(f"your name is {name} and your age is {age}")

# %%
hello(age = 22,name = "Kamran")
# Out:
# your name is Kamran and your age is 22

# %% [markdown]
# * Second example shows how keyword argument works using this
# you can pass values in any order.

# %% [markdown]
# #### Default arguments

# %% [markdown]
# Provide fallback values.

# %% [markdown]
# **Third Example**

# %%
def greet(name="User"):
    print("Hello", name)

greet()
greet("Kamran")
# Out:
# Hello User
# Hello Kamran

# %%
def greet(name="guest"): 
    print(f"Hello ,{name}")
    
greet()                  #Use default value as guest
greet("Kamran")          # Use "Kamran"
# Out:
# Hello ,guest
# Hello ,Kamran

# %% [markdown]
# ***Why useful?***
#
# In ML:

# %% [markdown]
# train_model(epochs=10)

# %% [markdown]
# * Third example shows how default argument works here if you
# don’t pass any value still the function will run

# %% [markdown]
# ***

# %% [markdown]
# ### RETURN VALUES

# %% [markdown]
# #### Print vs Return

# %%
def add(a,b):
    print(a+b)

# %% [markdown]
# This displays value but does NOT give it back.

# %% [markdown]
# Correct approach:

# %%
def add(a,b):
    return a+b

result = add(2,3)
print(result)
# Out:
# 5

# %% [markdown]
# #### Mental model

# %%
print → talk to human
return → talk to program

# %% [markdown]
# ML pipelines use return, not print.

# %% [markdown]
# ##### What return actually does?
#
# * Sends value back
# * Stops function execution immediately

# %%
def test():
    return 5
    print("never runs")

# %% [markdown]
# ***

# %% [markdown]
# ### VARIABLE SCOPE

# %% [markdown]
# This causes many bugs.
#
# #### Local scope

# %% [markdown]
# def func():
#     x = 10
#     print(x)
#
# func()
# print(x)  # error

# %% [markdown]
# x only exists inside function
#
# #### Global scope

# %%
x = 10

def func():
    print(x)

func()
# Out:
# 10

# %% [markdown]
# Function can read global variables.
#
# #### Modifying global (dangerous)

# %%
x = 10

def func():
    global x
    x = 20

# %% [markdown]
# Avoid in ML pipelines → leads to unpredictable behavior.

# %% [markdown]
# ***

# %% [markdown]
# ### 📦 Variable-Length Arguments (*args & **kwargs)
# Sometimes we don't know beforehand how many arguments a user might pass. Python provides `*args` and `**kwargs` for this.
#
# #### 🔹 1. *args (Non-keyword / Positional arguments)
# * The `*` unpacking operator gathers positional arguments into a **tuple**.
# * Useful when writing utility functions like summing numbers or joining text strings.

# %%
def sum_all(*args):
    print(type(args), args)
    total = 0
    for num in args:
        total += num
    return total

print("Sum:", sum_all(1, 2, 3, 4, 5))

# %% [markdown]
# #### 🔹 2. **kwargs (Keyword arguments)
# * The `**` unpacking operator gathers named/keyword arguments into a **dictionary**.
# * Widely used in ML configurations and API calls to pass hyperparameters dynamically.

# %%
def print_hyperparameters(**kwargs):
    print(type(kwargs), kwargs)
    for model_param, value in kwargs.items():
        print(f"Hyperparameter - {model_param}: {value}")

print_hyperparameters(learning_rate=0.01, epochs=100, optimizer="adam")

# %% [markdown]
# #### 🔹 3. Mixing Parameter Types
# * **Rule of order:** Positional parameters first → `*args` → Default parameters → `**kwargs`.
# * Breaking this order results in a `SyntaxError`.

# %%
def train_model(model_name, *args, epochs=10, **kwargs):
    print(f"Training Model: {model_name}")
    print(f"Positional args: {args}")
    print(f"Epochs: {epochs}")
    print(f"Additional settings (kwargs): {kwargs}")

train_model("RandomForest", "dataset_v1", "verbose_mode", epochs=50, max_depth=10, min_samples_split=2)

# %% [markdown]
# ***

# %% [markdown]
# ### 📝 Docstrings & Function Annotations (Type Hinting)
# Good code is self-documenting. In industry settings (and large ML codebases), docstrings and type hints are mandatory.
#
# #### 🔹 1. Docstrings (`__doc__`)
# * Triple-quoted strings placed immediately after the function header.
# * Explains the function's purpose, parameters, and return value.
# * Accessible via `help(function_name)` or `function_name.__doc__`.

# %%
def calculate_bmi(weight: float, height: float) -> float:
    """
    Calculate the Body Mass Index (BMI).
    
    Parameters:
    weight (float): Weight in kilograms.
    height (float): Height in meters.
    
    Returns:
    float: Calculated Body Mass Index.
    """
    return weight / (height ** 2)

# Accessing documentation
print(calculate_bmi.__doc__)

# %% [markdown]
# #### 🔹 2. Type Hinting / Annotations
# * Introduced in Python 3.5 to suggest types for parameters (`param: type`) and return value (`-> return_type`).
# * **Note:** Python remains a dynamically typed language; type annotations are ignored at runtime but are checked by IDEs and linters (like `mypy`).

# %%
def greet_user(name: str) -> str:
    return f"Hello, {name}!"

print(greet_user("Alice"))

# %% [markdown]
# ***

# %% [markdown]
# ### ⚡ Anonymous (Lambda) Functions
# Lambda functions are small, one-line functions that do not have a name. They are defined using the `lambda` keyword.
#
# #### 🔹 Syntax:
# `lambda arguments: expression`
#
# * They are limited to a single expression.
# * They automatically return the result of that expression.
# * Used for short-term, throwaway logic (e.g., in pandas `apply`, sorting, or higher-order functions).

# %%
# Standard function
def square(x):
    return x * x

# Equivalent Lambda function
square_lambda = lambda x: x * x

print("Standard:", square(5))
print("Lambda:", square_lambda(5))

# %%
# Lambda with multiple arguments
add_lambda = lambda a, b: a + b
print("Sum:", add_lambda(10, 20))

# %% [markdown]
# ##### 🧠 Real-world Data Science / ML Usage: Sorting tuples/dictionaries by value

# %%
# List of tuples containing (feature_name, importance_score)
feature_importance = [("Age", 0.15), ("Salary", 0.45), ("Location", 0.10), ("Education", 0.30)]

# Sort by importance score (second element in tuple)
feature_importance.sort(key=lambda item: item[1], reverse=True)
print("Sorted Feature Importance:", feature_importance)

# %% [markdown]
# ***

# %% [markdown]
# ### ⚙️ Higher-Order Functions (map, filter, reduce)
# A higher-order function is a function that either takes a function as an argument, or returns a function.
#
# #### 🔹 1. map()
# * Applies a function to all items in an iterable.
# * Syntax: `map(function, iterable)`

# %%
numbers = [1, 2, 3, 4, 5]
squared = list(map(lambda x: x**2, numbers))
print("Squared Numbers:", squared)

# %% [markdown]
# #### 🔹 2. filter()
# * Filters elements from an iterable based on whether a function returns `True` or `False`.
# * Syntax: `filter(function, iterable)`

# %%
scores = [85, 42, 90, 50, 78, 61]
passed = list(filter(lambda x: x >= 60, scores))
print("Passing Scores:", passed)

# %% [markdown]
# #### 🔹 3. reduce()
# * Applies a function cumulatively to items in an iterable to reduce it to a single value.
# * Must be imported from the `functools` module.

# %%
from functools import reduce

nums = [1, 2, 3, 4, 5]
# Calculates: ((((1 * 2) * 3) * 4) * 5)
factorial_of_5 = reduce(lambda x, y: x * y, nums)
print("Factorial (using reduce):", factorial_of_5)

# %% [markdown]
# ***

# %% [markdown]
# ### 🔄 Recursion
# Recursion is a programming technique where a function calls itself directly or indirectly to solve a problem.
#
# #### 🔹 First Principles:
# For a recursive function to work correctly and not crash the program, it must have two parts:
# 1. **Base Case:** The stopping condition that prevents infinite loops.
# 2. **Recursive Case:** The part where the function calls itself with a smaller input.
#
# #### 🧠 The Call Stack & Stack Overflow
# Each recursive call creates a new stack frame in memory. If the base case is missing or never reached, Python will raise a `RecursionError` (maximum recursion depth exceeded) to prevent stack overflow.

# %%
# Factorial using Recursion: n! = n * (n-1)!
def factorial(n):
    # 1. Base Case
    if n == 0 or n == 1:
        return 1
    # 2. Recursive Case
    else:
        return n * factorial(n - 1)

print("Factorial of 5:", factorial(5))

# %%
# Fibonacci Series using Recursion: F(n) = F(n-1) + F(n-2)
def fibonacci(n):
    # Base Cases
    if n <= 0:
        return 0
    elif n == 1:
        return 1
    # Recursive Case
    else:
        return fibonacci(n - 1) + fibonacci(n - 2)

print("6th Fibonacci number:", fibonacci(6))

# %% [markdown]
# ##### 🧠 ML/AI Relevance:
# * Tree-based algorithms (like Decision Trees, Random Forests, Gradient Boosting) are naturally built using recursive split processes on datasets.
# * Parsing hierarchical data structures (like ASTs, JSON configuration trees, HTML parse trees) is most cleanly achieved using recursion.

# %% [markdown]
# ***

# %% [markdown]
# ### 🔗 Introduction to Nested Functions & Closures
# A nested function is a function defined inside another function.
#
# #### 🔹 What is a Closure?
# A closure is a nested function that remembers and has access to variables in its enclosing (outer) scope, even after the outer function has finished executing.
#
# #### 🔹 Requirements for a Closure:
# 1. We must have a nested function.
# 2. The nested function must refer to a value defined in the enclosing function.
# 3. The enclosing function must return the nested function.

# %%
def power_factory(exponent):
    # Outer function scope variable: exponent
    def power_function(base):
        # Inner function has access to exponent
        return base ** exponent
    return power_function

# Create specific power functions
square_func = power_factory(2)
cube_func = power_factory(3)

print("5 squared:", square_func(5))
print("5 cubed:", cube_func(5))

# %% [markdown]
# ##### 🎯 Transition to Decorators:
# Closures are the foundational concepts behind **Decorators**, which allow us to wrap functions to modify or audit their behavior (e.g., timing execution, caching, logging). We will explore Decorators in depth in Chapter 12.

# %% [markdown]
# ## 📝 Practice Questions

# %% [markdown]
# ### 🟢 Easy Level

# %%
#Q1 Write a function `add_numbers(a, b)` that returns the sum of two numbers.

# %%
#Q2 Write a function `is_even(n)` that returns True if a number is even, and False otherwise.

# %%
#Q3 Write a function `triangle_area(base, height)` that returns the area of a triangle.

# %%
#Q4 Write a lambda function that calculates the square of a number and test it.

# %%
#Q5 Write a function `is_vowel(char)` that checks if a character is a vowel.

# %%
#Q6 Write a function `f_to_c(fahrenheit)` that converts temperature to Celsius.

# %%
#Q7 Write a function `greet(name, greeting='Hello')` that prints a greeting message.

# %%
#Q8 Write a function that accepts a list and prints each element on a new line.

# %%
#Q9 Write a function that returns both the area and perimeter of a square.

# %%
#Q10 Write a function to check if a string is empty.

# %%
#Q11 Write a function to calculate the factorial of a number using a standard loop.

# %%
#Q12 Write a function that checks if a string is a palindrome.

# %% [markdown]
# ### 🟡 Medium Level

# %%
#Q13 Write a recursive function to calculate the factorial of a number.

# %%
#Q14 Write a recursive function to find the N-th Fibonacci number.

# %%
#Q15 Write a function `custom_map(func, lst)` that behaves exactly like Python's built-in `map()`.

# %%
#Q16 Write a function `custom_filter(func, lst)` that behaves exactly like Python's built-in `filter()`.

# %%
#Q17 Write a function `sum_all(*args)` that accepts any number of arguments and returns their sum.

# %%
#Q18 Write a function `print_kwargs(**kwargs)` that prints all keys and values passed as keyword arguments.

# %%
#Q19 Write a closure `call_counter()` that returns a function which counts and prints how many times it has been called.

# %%
#Q20 Write a function that modifies a passed list in place by doubling each value.

# %%
#Q21 Write a function that demonstrates global variable modification using the `global` keyword.

# %%
#Q22 Write a lambda function inside another function to double a passed number.

# %% [markdown]
# ### 🔴 Hard Level

# %%
#Q23 Write a function `pipeline(val, funcs)` that applies a list of functions sequentially to a value.

# %%
#Q24 Write a recursive function to flatten a nested list of arbitrary depth.

# %%
#Q25 Write a recursive function to search for a key in a nested dictionary and return its value.

# %%
#Q26 Write a decorator simulator function that wraps another function and prints arguments and execution result.

# %%
#Q27 Write a curried version of a function that adds three numbers (e.g. `add(a)(b)(c)`).

# %%
#Q28 Write a generator function `fib_generator(limit)` that yields Fibonacci numbers up to a certain limit.

# %%
#Q29 Write a function to check if a function is a generator function using the `inspect` module.

# %%
#Q30 Implement a custom version of `functools.reduce` that applies a function cumulatively to list elements.
