# %% [markdown]
# <!-- Cache bust 34f0ef8d-2771-4a66-9a18-6e8b1051e1ba -->

# %% [markdown]
# # Operators & Expressions
#
# ***

# %% [markdown]
# #### What is an Operator? What is an Expression?
#
# **Operator** → Symbol that performs an operation
#
# **Expression** → Combination of values + operators that produces a result
# Example:
#
# x = 10 + 5
#
# + → operator
#
# 10 + 5 → expression
#
# ***

# %% [markdown]
# ##### In Simple terms :
# Operators are symbols that perform operations on variables
# and values. Python has several types of operators for
# different tasks like arithmetic, comparison, logical operations,
# and more

# %% [markdown]
# ### Arithmetic Operators
#
# * Used for numeric computation (core of ML)
# * Arithmetic operators perform mathematical operations like
# addition, subtraction, multiplication, division, etc
# * There are 7 types of arithmetic operator.

# %% [markdown]
# | Operator | Meaning        | Example       |
# | -------- | -------------- | ------------- |
# | `+`      | Addition       | `3 + 2 = 5`   |
# | `-`      | Subtraction    | `5 - 2 = 3`   |
# | `*`      | Multiplication | `4 * 2 = 8`   |
# | `/`      | Division       | `5 / 2 = 2.5` |
# | `//`     | Floor division | `5 // 2 = 2`  |
# | `%`      | Modulus        | `5 % 2 = 1`   |
# | `**`     | Power          | `2 ** 3 = 8`  |

# %% [markdown]
# ##### 🧠 ML relevance
#
# * Loss calculations
# * Gradient updates
# * Feature scaling
# * Epoch & batch math

# %%
#Addition
a = 55
b = 10
c = a + b
print(c)
# Out:
# 65

# %%
#Subtraction
num1 = 50
num2 = 15
sub = num1 - num2
print(sub)
# Out:
# 35

# %%
#Multiplication
num_1 = 10
num_2 = 100
mul = num_1 * num_2
print(mul)
# Out:
# 1000

# %%
#Division
m = 25
n = 5
print("Division of m & n is : ",m/n)
# Out:
# Division of m & n is :  5.0

# %%
#Floor division
num_01 = 10
num_02 = 3
f_div = num_01 // num_02
print(f_div)
# Out:
# 3

# %%
#Modulus
A = 17
B = 5
print(A % B)
# Out:
# 2

# %%
#Power
Aa = 3
Bb = 3
print("Power of Aa & Bb is : ",Aa**Bb)
# Out:
# Power of Aa & Bb is :  27

# %% [markdown]
# ### Assignment Operators

# %% [markdown]
# * Assignment operators are used to assign values to variables.
# * Python also provides compound assignment operators that
# perform operations like addition, subtraction, multiplication,
# etc
# * A basic assignment operator is simple =.

# %%
num = 56

# %%
name = "KK"

# %% [markdown]
# ***

# %% [markdown]
# ### Compound Assignment Operator

# %% [markdown]
# * Compound assignment operator combines arithmetic
# operations with assignment
# * Using compound assignment operators the reassigning
# works better

# %% [markdown]
# | Operator |        Meaning            | Example       |
# | -------- | ------------------------  | ------------- |
# | `+=`     | Add and assign            | `a += 20`     |
# | `-=`     | Subtract and assign       | `a -= 2`      |
# | `*=`     | Multiply and assign       | `b *= 40`     |
# | `/=`     | Divide and assign         | `c /= 25`     |
# | `//=`    | Floor divide and assign   | `c //= 30`    |
# | `%=`     | Modulus and assig         | `d %= 2`      |
# | `**=`    | Exponentiation and assign | `a **= 3`     |

# %%
# += Add and Assign

a= 20
a += 40
print(a)
# Out:
# 60

# %%
a += 40
print(a)
# Out:
# 100

# %%
# *= Multiply and Assign

a *= 5
print(a)
# Out:
# 500

# %%
# /= Divide and Assign

a /= 5
print(a)
# Out:
# 100.0

# %%
# **= Exponentiation and Assign

a **= 2
print(a)
# Out:
# 10000.0

# %% [markdown]
# ***

# %% [markdown]
# ### Comparison Operators

# %% [markdown]
# * Comparison operators, also called relational operators, are
# used to compare two values
# * Comparison operators will always provide Boolean result that
# is True and False
# * Comparison operators will work with numbers but you can
# use them with strings as well.
# * Strings will be comparing the Ascii values of string.
# * comparison operators are as follows :

# %% [markdown]
# | Operator | Meaning          |
# | -------- | ---------------- |
# | `==`     | Equal            |
# | `!=`     | Not equal        |
# | `>`      | Greater          |
# | `<`      | Less             |
# | `>=`     | Greater or equal |
# | `<=`     | Less or equal    |

# %% [markdown]
# ##### 🧠 Used in ML
#
# * Early stopping
# * Threshold checks
# * Accuracy conditions

# %%
#Equal
a = 3
b = 3
if a==b:
    print(True)
# Out:
# True

# %%
#Not equal
A = 55
B = 6
if A!=B:
    print("Not Same")
# Out:
# Not Same

# %%
#Greater
n=55 
m=5
if n > m:
    print("n is Greater than m")
else:
    print("m is Greater than n")
# Out:
# n is Greater than m

# %%
#Less
num_11= 20
mum_22= 44
if n < m:
    print("num_11 is Less than num_22")
else:
    print("num_22 is Less than num_11")
# Out:
# num_22 is Less than num_11

# %%
#Greater or equal
E = 6000
F = 6000
if E >= F:
    print("Both are Equals")
else:
    print("E is greater than F")
# Out:
# Both are Equals

# %%
#To find Ascii value
print(ord("a"))
# Out:
# 97

# %%
print(ord("A"))
print(ord("B"))

print("A" > "B")
# Out:
# 65
# 66
# False

# %%
print("ABC" > "ADC")
# Out:
# False

# %%
print("A" > 34)    # we can not compare string with integer
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[31], line 1
# ----> 1 print("A" > 34)    # we can not compare string with integer
#
# TypeError: '>' not supported between instances of 'str' and 'int'

# %% [markdown]
# ***

# %% [markdown]
# ### Logical Operators

# %% [markdown]
# * Logical operators in Python are used to combine multiple
# conditions and return a Boolean result (True or False)
# *  Used to combine conditions.
# * * and   - Return True if both condition are True
# * *  or      - Return True if at least one condition is True
# * *  not    - Reverse the boolean value

# %% [markdown]
# | Operator | Meaning           |
# | -------- | ----------------- |
# | `and`    | Both true         |
# | `or`     | At least one true |
# | `not`    | Negation          |

# %%
a = 10
b = 100
c = 20
if b> a and  b > c:
    print("b is bigger")
# Out:
# b is bigger

# %%
if a > b or  c < b:
    print("B is Bigger no.")
# Out:
# B is Bigger no.

# %%
print(30 > 20 and 10 >5 and 110 < 200)              # It gives true if all the codition are true
# Out:
# True

# %%
print(10 > 20 and 10 >5 and 110 > 200)
# Out:
# False

# %%
print((456 == 456) != (235 == 236))
# Out:
# True

# %%
print(True and bool(0))
# Out:
# False

# %%
print(30 > 20 or 10 >5 or 110 < 200)
# Out:
# True

# %%
print(10 > 20 or 10 >50 or 110 < 200)           # It gives true if any one codition is true
# Out:
# True

# %%
print(10 > 20 or 10 >50 or 1010 < 200)
# Out:
# False

# %%
print(12 < 10 or 45 == 56 or 69 > 70 or 15 != 13)
# Out:
# True

# %%
print(not 12 == 12)
# Out:
# False

# %%
print(not 12 == 22)
# Out:
# True

# %% [markdown]
# ***

# %% [markdown]
# ### 🧠 Short-circuiting

# %%
False and expensive_function()  # function NOT called

# %% [markdown]
# ##### Used for:
#
# * Performance optimization
# * Safe ML pipelines
# ***

# %% [markdown]
# ### Bitwise Operators
#
# Operate on binary representation
#
# | Operator | Meaning        |    |
# | -------- | -------------  | -- |
# | `&`      | AND            |    |
# | `        | `              | OR |
# | `^`      | XOR            |    |
# | `~`      | NOT            |    |
# | `<<`     | Left shift     |    |
# | `>>`     | Right shift    |    |

# %%
5 & 3   # 101 & 011 = 001 → 1

# %% [markdown]
# ##### 🧠 Real usage
#
# * Flags
# * Hashing
# * Optimization tricks
# * Masking in ML & NumPy
# ***

# %% [markdown]
# ### Operator Precedence
#
# Order in which expressions are evaluated.
#
# **🔝 High → Low**
#
# *1.* ()
#
# *2.* **
#
# *3.* *, /, //, %
#
# *4.* +, -
#
# *5.* Comparison (<, >, ==)
#
# *6.* not
#
# *7.* and
#
# *8.* or

# %%
10 + 2 * 3   # 16, not 36
# Out:
# 16

# %%
(10 + 2) * 3       #Best practice:
# Out:
# 36

# %% [markdown]
# ***

# %% [markdown]
# ### Expressions in ML Pipelines (Real-world)

# %% [markdown]
# ##### 🔹 Feature normalization

# %% [markdown]
# x = (x - mean) / std

# %% [markdown]
# ##### 🔹 Loss function

# %% [markdown]
# loss = (y_true - y_pred) ** 2

# %% [markdown]
# ##### 🔹 Early stopping

# %% [markdown]
# if loss < threshold and epoch > min_epoch:
#     stop_training = True

# %% [markdown]
# ##### 🔹 Masking (advanced)

# %% [markdown]
# mask = (x > 0) & (x < 1)

# %% [markdown]
# ## 📝 Practice Questions

# %% [markdown]
# ### 🟢 Easy Level

# %%
#Q1 Write a program to add, subtract, multiply, and divide two numbers.
n1=17
n2= 15 
add=n1+n2
sub=n1-n2 
divide= n1/n2 
mul=n1 *n2 
print( add , sub , divide, mul)
# Out:
# 32 2 1.1333333333333333 255

# %%
#Q2 Write a program to calculate floor division and modulo of two numbers.
print(n1// n2 , n1%n2)
# Out:
# 1 2

# %%
#Q3 Write a program to calculate the exponentiation of a number (base raised to power).
n_1= 5
print(n_1**n_1)
# Out:
# 3125

# %%
#Q4 Write a program to demonstrate assignment operators (+=, -=, *=, /=).

# %%
#Q5 Write a program to check if a number is greater than, less than, or equal to another number.
num1 = float(input("Enter the first number: "))
num2 = float(input("Enter the second number: "))
if num1 > num2:
    print(f"{num1} is greater than {num2}")
elif num1 < num2:
    print(f"{num1} is less than {num2}")
else:
    print(f"{num1} is equal to {num2}")

# %%
#Q6 Write a program to show logical operators (and, or, not) with boolean values.

# %%
#Q7 Write a program to verify if an element is present in a list using the membership operator `in`.

# %%
#Q8 Write a program to check if two variables point to the same object using the identity operator `is`.

# %%
#Q9 Write a program to compare two strings alphabetically using comparison operators.

# %%
#Q10 Write a program to check if a number is odd using the modulo operator.

# %%
#Q11 Write a program to check if a number is divisible by 5 and 11 using logical operators.

# %%
#Q12 Write a program to verify operator precedence by calculating '5 + 2 * 3' vs '(5 + 2) * 3'.

# %% [markdown]
# ### 🟡 Medium Level

# %%
#Q13 Write a program to demonstrate bitwise AND, OR, and XOR operations on two integers.

# %%
#Q14 Write a program to perform left shift and right shift operations on an integer.

# %%
#Q15 Write a program to demonstrate bitwise NOT operator on a positive integer.

# %%
#Q16 Write a program to implement short-circuit evaluation using functions that print messages.

# %%
#Q17 Write a program to check if a character is a vowel using the `in` operator.

# %%
#Q18 Write a program to chain comparison operators to check if a number lies in a specific range.

# %%
#Q19 Write a program to compute the XOR of two boolean variables without using comparison or logical operators.

# %%
#Q20 Write a program to perform integer division and obtain both quotient and remainder simultaneously using `divmod()`.

# %%
#Q21 Write a program to verify if a key exists in a dictionary using the `in` operator.

# %%
#Q22 Write a program to calculate the absolute value of a number using comparison and arithmetic operators.

# %% [markdown]
# ### 🔴 Hard Level

# %%
#Q23 Write a program to swap two integers using only bitwise XOR operator without a temp variable.

# %%
#Q24 Write a program to count the number of set bits (1s) in the binary representation of an integer using bitwise operations.

# %%
#Q25 Write a program to check if a number is a power of 2 using bitwise operators.

# %%
#Q26 Write a program to extract the last digit of an integer using arithmetic operators, handling negative numbers correctly.

# %%
#Q27 Write a program to calculate floating-point modula (e.g., 5.5 % 1.2) using standard operators and math module.

# %%
#Q28 Write a program to create a custom class that overloads the addition operator `+` using magic methods.

# %%
#Q29 Write a program to evaluate logical operations represented as string expressions dynamically.

# %%
#Q30 Write a program to calculate the Jaccard similarity between two sets using set operators.
