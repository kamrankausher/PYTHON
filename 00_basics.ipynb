# %% [markdown]
# <!-- Cache bust 8822dd97-5d27-46c2-8055-d77dcff783ba -->

# %% [markdown]
# #                                                              PYTHON

# %% [markdown]
# ***

# %% [markdown]
# ### Python from Zero → Advanced for AI, ML, GenAI & Agentic AI

# %% [markdown]
# #### What is Programming?
# Programming = Giving instructions to a computer to solve problems automatically.
#
# Programming is:
# 1. Breaking a problem into logical steps
# 2. Writing those steps in a language computers understand
# 3. Ensuring correctness, efficiency, and reusability

# %% [markdown]
# #### How Python Executes Code?
# -> You write .py file
#
# -> Python converts code → bytecode
#
# -> Bytecode runs on Python Virtual Machine (PVM)

# %% [markdown]
# #### Interpreted vs Compiled:
# ##### Compiled language (C++)
#
# 1. Code → Machine code → Run
# 2. Faster execution
# 3. Harder to debug
#
# ##### Interpreted language (Python)
#
# 1. Code executed line by line
# 2. Easier debugging
# 3. Slower speed
#
# **#Important note :** Python is:
#
# ##### Both compiled (to bytecode) AND interpreted (by PVM)

# %% [markdown]
# ***

# %% [markdown]
# ### Where Python is Used :
# #### 📊 Data Science
#
# 1. Data cleaning (Pandas)
# 2. Analysis
# 3. Visualization
# 4. Statistics
#
# #### 🤖 Machine Learning
#
# 1. Feature engineering
# 2. Model training
# 3. Evaluation
# 4. Deployment scripts
#
# #### 🧠 Deep Learning
#
# 1. Neural networks
# 2. GPU computing
# 3. Research & production
#
# #### ✨ Generative AI
#
# 1. Text generation
# 2. Image generation
# 3. RAG systems
# 4. Prompt pipelines
#
# #### 🧩 Agentic AI
#
# 1. Autonomous agents
# 2. Tool calling
# 3. Memory systems
# 4. Multi-agent workflows
#
# ##### 👉 Python is the brain language of AI systems

# %% [markdown]
# ***

# %% [markdown]
# ### Running Python Code:
# #### 🔹 1. REPL (Interactive mode)
#
# Type code → instant output
#
# Used for testing ideas
#
# #### 🔹 2. Script (.py file)
#
# Write full program
#
# Used in projects, ML pipelines
#
# #### 🔹 3. IDE / Notebook
#
# VS Code
#
# Jupyter Notebook
#
# Used in Data Science & research
#
# #### 🧠 Industry reality
#
# Jupyter → experiments
#
# Scripts → production
#
# IDE → large projects

# %% [markdown]
# ***

# %% [markdown]
# ### Our first Program :

# %%
print("HELLO WORLD")    #To print anything we use print()
# Out:
# HELLO WORLD

# %% [markdown]
# ***

# %% [markdown]
#   ### Comments in python

# %% [markdown]
# * Comments are something that are ignored by the python
# interpreter
# * We have to use **#** for writing a comment in python
# * Multiline comments are not available in python but we can
# achieve it by using Doc String
# **“”” Multiline ”””**

# %%
#This is Single line Comment

# %% [markdown]
# ***

# %% [markdown]
# ### INPUT / OUTPUT & DEBUGGING MINDSET

# %% [markdown]
# #### INPUT()

# %% [markdown]
# What input() actually does

# %%
name = input("Enter name: ")
# Out:
# Enter name:  Kamran

# %% [markdown]
# ##### Internally Python does:
#
# * Pauses program execution
# * Waits for keyboard text
# * Reads characters as string
# * Stores in variable
#
# ##### 👉 Important truth:
# input() ALWAYS returns a string
#
# **Even if user types:**

# %%
a= input()
b=input()
print(a+b)
# Out:
#  2
#  5
# 25

# %% [markdown]
# Python stores: "25" as string

# %%
a= int(input())
b=int(input())
print(a+b)
# Out:
#  2
#  5
# 7

# %% [markdown]
# #### Multi-value input

# %%
#a, b = map(int, input().split())

# %% [markdown]
# ##### What happens step-by-step
#
# input → "10 20"
#
# split → ["10","20"]
#
# map int → [10,20]
#
# unpack → a=10, b=20
#
# This pattern is used in competitive coding & ML datasets.

# %% [markdown]
# #### OUTPUT

# %%
print("Hello")
# Out:
# Hello

# %% [markdown]
# ##### Multiple values

# %%
print("AI", "ML", "DL")
# Out:
# AI ML DL

# %% [markdown]
# Default separator = space

# %% [markdown]
# ##### Custom separator

# %%
print("AI","ML","DL", sep="-")
# Out:
# AI-ML-DL

# %% [markdown]
# ##### Ending control

# %%
print("Hello", end="")
print("World")
# Out:
# HelloWorld

# %% [markdown]
# ##### Formatted output

# %%
name="AI"
version=4
print(f"{name} version {version}")
# Out:
# AI version 4

# %%
Name=input("Enter your name")
Greet="Good Morning"
Message="Welcome to Python Course"
print(f"{Greet} {Name} {Message}")
# Out:
# Enter your name Kamran
# Good Morning Kamran Welcome to Python Course

# %% [markdown]
# ##### Why f-strings matter:
#
# * readable
# * safe
# * widely used in ML logging & prompts

# %% [markdown]
# ***

# %% [markdown]
# #### DEBUGGING MINDSET

# %% [markdown]
# Programming = removing confusion step-by-step.
# Not guessing

# %% [markdown]
# ##### PROGRAMMER MENTAL MODEL
#
# **Bad coder:**
#
# Writes code → hopes it works
#
# **Good coder:**
#
# Predicts behavior → verifies → fixes

# %% [markdown]
# ##### 🎯 WHY THIS MATTERS FOR AI / ML
#
# In AI:
#
# * wrong preprocessing = wrong model
# * wrong input parsing = bad dataset
# * silent bug = incorrect training
#
# Most ML failures are data bugs, not math bugs

# %%
a = 10
b = 20
avg = a + b / 2
print(avg)
# Out:
# 20.0

# %%
avg = (a + b) / 2    #fix
print(avg)
# Out:
# 15.0

# %% [markdown]
# ##### Reasoning
#
# Operator precedence → division happens first.

# %% [markdown]
# ***

# %% [markdown]
# ### type()
#
# Shows data type

# %% [markdown]
# type(10) → int
#
# type("10") → str

# %%
n=10
type(n)
# Out:
# int

# %%
type("n")
# Out:
# str

# %%
type("19")
# Out:
# str

# %% [markdown]
# ### id()
#
# Memory identity

# %%
x = 10
print(id(x))
# Out:
# 140717732111560

# %% [markdown]
# Used to understand mutability.

# %% [markdown]
# ### len()
#
# Works on sequences

# %%
len("AI")
# Out:
# 2

# %%
len([1,2,3])
# Out:
# 3

# %% [markdown]
# ### SYS MODULE (IMPORTANT FOR INPUT SPEED)

# %%
import sys
data = sys.stdin.readline()

# %% [markdown]
# Why used?
#
# Fast input for large datasets (competitive coding, big logs).

# %% [markdown]
# ## 📝 Practice Questions

# %% [markdown]
# ### 🟢 Easy Level

# %%
#Q1 Write a program to print 'Hello, World!'.
print("hello world")
# Out:
# hello world

# %%
#Q2 Write a program to print 'Welcome to python notes repo' using variables.
note= "Welcome to python notes repo"
print(note)
# Out:
# Welcome to python notes repo

# %%
#Q3 Write a program to print three different values (name, age, city) in a single print statement separated by '|'.
name= "Kamran kausher"
age= 24
city= "Bengaluru"
print(name , age , city, sep='/')
# Out:
# Kamran kausher/24/Bengaluru

# %%
#Q4 Write a program to print 'Hello' and 'World' on the same line with a space in between, but using two separate print statements.\
print("Hello", end= " ")
print("World")
# Out:
# Hello World

# %%
#Q5 Write a program to accept the user's name as input and print a customized greeting.
name=input("Enter your name")
Greet= "Good Morning"
print(f"{Greet} {name} , How are you doing? " )
# Out:
# Enter your name Kamran
# Good Morning Kamran , How are you doing?

# %%
#Q6 Write a program to calculate the area of a rectangle given length and width from user input.
length = int(input("Enter length: "))
width = int(input("Enter width: "))

area = length * width

print("Area of rectangle is:", area)
# Out:
# Enter length:  4
# Enter width:  6
# Area of rectangle is: 24

# %%
#Q7 Write a program to calculate simple interest based on Principal, Rate, and Time inputs.

# %%
#Q8 Write a program to swap the values of two variables using a temporary variable.
a = 10
b = 20

temp = a
a = b
b = temp

print("a =", a)
print("b =", b)
# Out:
# a = 20
# b = 10

# %%
#Q9 Write a program to print the type of three variables: integer, float, and string.
intg= 45
fl = 45.5
strn= "45"
print(type(intg), type(fl), type(strn))
# Out:
# <class 'int'> <class 'float'> <class 'str'>

# %%
#Q10 Write a program to calculate the perimeter of a square when the side length is given by the user.
side= int(input("Enter side of a square : "))
perimeter = side + side + side+ side
print(perimeter)
# Out:
# Enter side of a square :  2
# 8

# %%
#Q11 Write a program to print the square of a number input by the user.
n=int(input("Enter number"))
print(n**2)
# Out:
# Enter number 10
# 100

# %%
#Q12 Write a program to output a paragraph containing double quotes using escape characters.

# %% [markdown]
# ### 🟡 Medium Level

# %%
#Q13 Write a program that demonstrates fast input reading using the sys module.
import sys
data = sys.stdin.readline()

# %%
#Q14 Write a program to print the ASCII value of a character given by the user.
letter= input("Enter a character :")
print(ord(letter))
# Out:
# Enter a character : B
# 66

# %%
#Q15 Write a program to format and print a floating-point number to exactly 3 decimal places.

# %%
#Q16 Write a program to print the quotient and remainder of two numbers using division operators.
A= 33
B= 5
rem= A % B
qt= A // B 
print(f "Reminder : {rem} Quotinet is :{qt}")
# Out:
#   Cell In[10], line 6
#     print(f "Reminder : {rem} Quotinet is :{qt}")
#             ^
# SyntaxError: invalid syntax

# %%
#Q17 Write a program to get three space-separated integers from a single input line.
print(34 , 44, 700,  sep="   ")
# Out:
# 34   44   700

# %%
#Q18 Write a program to display the size in bytes of an integer variable using the sys module.

# %%
#Q19 Write a program to convert minutes into hours and minutes (e.g., 135 minutes -> 2 hours 15 minutes).

# %%
#Q20 Write a program to evaluate the result of 2 raised to the power of 10 and print it as a formatted string.

# %%
#Q21 Write a program to print the current directory path (using sys or os).

# %%
#Q22 Write a program to dynamically prompt the user and print the variable memory address using id().

# %% [markdown]
# ### 🔴 Hard Level

# %%
#Q23 Write a program to redirect standard output (stdout) to a file named 'output.txt' temporarily and print 'Hello File'.

# %%
#Q24 Write a program to measure the exact execution time of a print statement in microseconds.

# %%
#Q25 Write a program to construct and print a dynamic ASCII text banner based on user input length.

# %%
#Q26 Write a program to count total memory usage of a string as its length increases from 1 to 100 characters.

# %%
#Q27 Write a program to print all the system paths in sys.path line-by-line.

# %%
#Q28 Write a program to implement a custom printing function using sys.stdout.write instead of print.

# %%
#Q29 Write a program to calculate compound interest using user inputs for Principal, Rate, Time, and frequency.

# %%
#Q30 Write a program to retrieve and print environment variables in a formatted table.
