# %% [markdown]
# <!-- Cache bust 3d2f6e9e-b4a9-4be7-b317-9c9b09b9c927 -->

# %% [markdown]
# # Control Flow (if, elif, else)

# %% [markdown]
# #### What is Control Flow? (First principles)
#
# Control flow determines:
#
# * Which code runs
# * Under what condition
# * In what order
#
# Without control flow:
#
# * Programs would always run line-by-line
# * No decisions
# * No intelligence
#
# **👉 AI systems are nothing but complex decision systems**
#
# ***

# %% [markdown]
# ### if Statement
# 🔹 Syntax

# %%
if condition:
    code_block

# %%
loss = 0.05

if loss < 0.1:
    print("Model is learning")

# %% [markdown]
# ##### 🧠 Important rule
#
# * Condition must evaluate to boolean
# * Indentation defines scope (very important in Python)

# %% [markdown]
# **Examples**

# %%
n = "Sum"
m = "Sum"
if n==m:
    print("Both are same")

# %%
loss= 0.2
accuracy = 0.9
if loss < 0.4 and accuracy > 0.7:
    print("Model is performing well")

# %% [markdown]
# ***

# %% [markdown]
# ### if-else
#
# Used when exactly one path must run.

# %%
if accuracy > 0.9:
    print("Good model")
else:
    print("Needs improvement")

# %%
#Q Accept two numbers and print the greatest between them.

num_1 = int(input("Enter a first number"))
num_2 = int(input("Enter a second number"))
if num_1 > num_2:
    print(f"{num_1} is Greater than {num_2}")
elif num_2 > num_1:
    print(f"{num_2} is Greater than {num_1}")
else:
    print("Both numbers are same")

# %%
#Q Accept the gender from the user as char and print the respective greeting message 

gender = str(input("Enter your gender - (Male or Female)"))
if gender == "Male" or gender == "male":
    print("Good Morning Sir")
elif gender == "Female" or gender == "female":
    print("Good Morning Ma'am")
else:
    print("Enter a valid Gender")

# %%
#Q  Accept an integer and check whether it is an even number or odd.

num = int(input("Enter a number"))
if num % 2 == 0:
    print(f"{num} is even Number")
else:
    print(f"{num} is odd Number")

# %%
#Q Accept name and age from the user. Check if the user is a valid voter or not.

name =input("Enter your Name")
age = int(input("Enter your Age"))
a= 18-age
if age >= 18 :
    print(f"{name} Your age is {age} , You are valid for Voter")
else:
    print(f"{name} Your age is {age} , Sorry! You are not  valid for Voter, \n You can vote after {a} Years ")

# %% [markdown]
# **👉 Either if OR else will execute, never both.**

# %% [markdown]
# ***

# %% [markdown]
# ### if-elif-else (Multiple decisions)
#
# Used when you have multiple mutually exclusive conditions

# %%
score = 87
if score >= 90:
    grade = "A"
elif score >= 75:
    grade = "B"
elif score >= 60:
    grade = "C"
else:
    grade = "Fail"
print(grade)

# %% [markdown]
# ##### 🧠 Execution rule
#
# * Checked top to bottom
# * First True block executes
# * Rest are skipped

# %% [markdown]
# ***

# %% [markdown]
# ### Nested Conditions (Conditions inside conditions)

# %%
model_trained =True
if model_trained:
    if accuracy > 0.9:
        print("Deploy model")
    else:
        print("Tune hyperparameters")

# %% [markdown]
# ***

# %% [markdown]
# ### Truthy & Falsy Values

# %% [markdown]
# **🔻 Falsy values in Python**
#
# These evaluate to False:
# * False
# * None
# * 0
# * 0.0
# * "" (empty string)
# * [] (empty list)
# * {} (empty dict)
# * set()
#
#  ***Everything else is Truthy.***

# %% [markdown]
# **🧠 Example**

# %%
data = []

if data:
    print("Data exists")
else:
    print("No data")

# %% [markdown]
# Used heavily in:
#
# * Data validation
# * ML pipelines
# * API checks

# %% [markdown]
# ***

# %% [markdown]
# ### Real Decision Logic in ML Systems

# %% [markdown]
# **🔹 Example 1: Early Stopping**

# %%
if loss < threshold and epoch > min_epoch:
    stop_training = True

# %% [markdown]
# **🔹 Example 2: Data Validation**

# %%
if not data:
    raise ValueError("Dataset is empty")

# %% [markdown]
# **🔹 Example 3: Model Selection**

# %%
if accuracy > best_accuracy:
    best_model = current_model

# %% [markdown]
# **🔹 Example 4: Inference Logic**

# %%
if confidence > 0.8:
    return "Accepted"
else:
    return "Rejected"

# %% [markdown]
# ***

# %% [markdown]
# ## Practice Questions

# %%
x = 0
if not x:
    print("Falsy")

# %%
x = ""
if x is "":               #is checks identity, not value
    print("Empty string")

# %%
x = 2
if x == 2 or x / 0 == 1:
    print("Safe")

# %%
x = []
y = []
if x == y:
    print("Equal")

# %%
x = []
if x is []:
    print("Same")
else:
    print("Different")

# %%
x = 1
if x:
    print("Yes")
elif x == 1:
    print("One")

# %%
x = 0
if x == False:
    if x is False:
        print("Boolean False")
    else:
        print("Integer Zero")

# %%
x = ""
if not x and x is not None:             #Both Conditions are True
    print("Empty but not None")

# %%
x = None
if x == False:
    print("False")
else:
    print("Not False")          #None ≠ False

# %%
val_loss = 0.5
best_loss = 0.5

if val_loss <= best_loss:
    print("Save model")

# %%
#Q1 Write a program to check whether a number is positive or negative.
n = -1
if n > 0:
    print("Number is Positive")
else:
    print("Number is Negative")

# %%
#Q2 Write a program to check whether a number is zero or non-zero.
if n == 0:
    print("Number is Zero")
else:
    print("Number is Non-Zero")

# %%
#Q3 Write a program to check whether a string is empty or not
str="Kamran"
if str == "":
    print("String is Empty")
else:
    print("String")

# %%
#Q4 Write a program to check whether a number is even or odd.
num = 101
if num % 2 == 0:
    print("Num. is even")
else:
    print("Num. is odd")

# %%
#Q5 Write a program to print “Pass” if marks are greater than or equal to 40, otherwise print “Fail”.
marks = 50
if marks >=40:
    pass
else:
    print("Fail")

# %%
#Q6 Write a program to check whether a variable contains None.
x = None
if x is None:
    print("None detected")

# %%
#Q7 Write a program to check whether a list is empty.
list= []
if list == []:
    print("List is Empty")
else:
    print("Not Empty")

# %%
#Q8 Write a program to check whether a boolean variable is True or False.
bool = False
if bool == True:
    print(True)
else:
    print(False)

# %%
#Q9 Write a program to check whether a number is greater than 100.
num_1 = 1002
if num_1 > 100:
    print("Greater than 100")
else:
    print("Not")

# %%
#Q10 Write a program to print “Valid” if a variable has any value, otherwise print “Invalid”.
Value = [44,"cat"]
if Value:
    print("Valid")
else:
    print("Invalid")

# %%
#Q11 Write a program to assign grades based on marks:
#≥ 90 → A
#≥ 75 → B
#≥ 60 → C
#Else → Fail

score= int(input("Enter Score"))
if score >= 90:
    Grade = "A"
elif score >= 75:
    Grade = "B"
elif score >= 60:
    Grade = "C"
else:
    Grade ="Fail"
print(Grade)

# %%
#Q12 Write a program to check whether a number lies between 1 and 10.
num = int(input("Enter a Number : "))
if num >=1 and num <=10:
    print("No. Lies between 1-10 ")
else:
    print("Not lies")

# %%
#Q13 Write a program to check whether a given year is a leap year or not.
year = int(input("Enter a Year : "))
if (year% 4 == 0 and year % 100 != 0) or (year % 400 == 0):
    print("Leap Year ")
else:
    print("Not a Leap Year")

# %%
#Q14 Write a program to check whether a number is positive, negative, or zero.
num_1 = -3
if num_1 > 0:
    print("Positive No.")
elif num_1 < 0:
    print("Negative No")
else:
    print("Zero")

# %%
#Q15 Write a program to check whether a user is eligible to vote (age ≥ 18).
age = int(input("Enter your Age"))
if age>=18:
    print("Eligible for vote")
else:
    print("Not Eligible")

# %%
#Q16 Write a program to check whether a number is divisible by both 3 and 5.
num = 30
if num % 3 == 0 and num % 5 == 0:
    print(num, ": is divisible by both 3 & 5")
else:
    print("Not divisible")

# %%
#Q17 Write a program to check whether a string contains any data before processing it.
text="AI"
if text:
    print("Contains data")
else:
    print("NO data")

# %%
#Q18 Write a program to check whether a value is None, zero, or a valid number. 
x = 0
if x is None:
    print("None value")
elif x == 0:
    print("Zero value")
else:
    print("Valid number")

# %%
#Q19 Write a program to check whether a list has data before training an ML model.
Data_set=[3,55]
if Data_set:
    print("Data available")
else:
    print("No data")

# %%
#Q20 Write a program to validate login where username and password must not be empty.
username = "admin"
password = "1234"
if username and password:
    print("Login successful")
else:
    print("Invalid login")

# %%
#Q21 Write a program to distinguish between integer zero and boolean False.
x = 0
if x == False and x is not False:
    print("Integer Zero")

# %%
#Q22 Write a program to check whether two variables refer to the same object.
a = [1, 2]
b = a
if a is b:
    print("Same object")

# %%
#Q23 Write a program to check whether two lists have the same values.
list_1=[3,33,"kk",50]
list_2=[3,33,"kk",50]
if list_1 == list_2:
    print("Same values")
else:
    print("Not same")

# %%
#Q24 Write a program to prevent division by zero using control flow.
a = 10
b = 0
if b == 0:
    print("Division not allowed")
else:
    print(a / b)

# %%
#Q25 Write a program to stop model training when loss is below a threshold.
loss = 0.03
threshold = 0.05
if loss < threshold:
    print("Stop training")

# %%
#Q26 Write a program to validate input before feeding it into an ML pipeline.
input_data = "Sample"
if input_data and input_data is not None:
    print("Input valid")

# %%
#Q27 Write a program to compare floating-point numbers safely.
a = 0.1 + 0.2
b = 0.3
if abs(a - b) < 1e-9:
    print("Approximately equal")

# %%
#Q28 Write a program to select the best model based on accuracy.
accuracy = 0.92
best_accuracy = 0.90
if accuracy > best_accuracy:
    print("Best model updated")

# %%
#Q29 Write a program to check whether a value is NaN and handle it properly.
x = float("nan")
if x != x:
    print("Invalid value")

# %%
#Q30 Write a program to ensure an ML prediction is made only when confidence > 0.8.
confidence = 0.9
if confidence>0.8:
    print("Prediction accepted")

# %%
#Q31 Write a program to save a model only when validation loss strictly improves.
val_loss = 0.4
best_loss = 0.5
if val_loss < best_loss:
    print("Model saved")

# %%
#Q32 Write a program to detect data leakage using control flow.
train_data = True
test_data = True
if train_data == test_data:
    print("Data leakage detected")

# %%
#Q33 Write a program to check whether training should continue based on both loss and epochs.
loss = 0.2
epoch = 15
if loss > 0.1 and epoch < 50:
    print("Continue training")

# %%
#Q34 Write a program to ensure an API request contains required fields before processing.
api ="khdhdhfnfxxxdhdj"
if api :
    print("Valid api key")
else:
    print("Invalid api key")

# %%
#Q35 Write a program to differentiate between empty data and missing data.
data =[]
if data is None:
    print("Missing data")
elif not data:
    print("Empty data")

# %%
#Q36 Write a program to prevent overwriting a good ML model due to noisy loss values

new_loss = 0.5001
best_loss = 0.5
tolerance = 0.01
if new_loss < best_loss - tolerance:
    print("Model updated")
else:
    print("Model retained")

# %%
#Q37 Write a program to handle fallback logic when a primary ML model fails.

primary_model = False
if primary_model:
    print("Primary model used")
else:
    print("Fallback model used")

# %%
#Q38 Write a program to block predictions when input confidence is too low.

confidence = 0.6
if confidence < 0.7:
    print("Prediction blocked")

# %%
#Q39 Write a program to validate batch size before training starts.

batch_size = 32
if batch_size > 0:
    print("Batch size valid")

# %%
#Q40 Write a program to decide whether an autonomous AI agent should act or wait.

should_act = False
environment_safe = True
if should_act and environment_safe:
    print("Agent acting")
else:
    print("Agent waiting")
