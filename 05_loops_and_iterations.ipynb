# %% [markdown]
# <!-- Cache bust 95251ba3-c8b4-4f7e-ac88-cf75d05acfac -->

# %% [markdown]
# # Loops & Iterations

# %% [markdown]
# ###  Why Loops Exist (First principles)
#
# Computers are fast at repetition.
# Loops let you:
# * Process large datasets
# * Train models over epochs
# * Apply transformations repeatedly
# * Implement algorithms (DSA)
#
# ##### Without loops:
#
# * No ML
# * No data pipelines
# * No training

# %% [markdown]
# ***

# %% [markdown]
# ###  for Loop (Iteration over sequences)
#
# Repeat for EACH item

# %% [markdown]
# **🔹 Syntax**

# %%
for variable in sequence:
    code_block

# %% [markdown]
# **🔹 Example**

# %%
for i in [1, 2, 3]:
    print(i)

# %%
name="KAMRAN"
for i in name:
    print(i)

# %%
L=["KK", 45,True, 60.5 ]
for x in L:
    print(x)

# %% [markdown]
# **🔹 Using range()**

# %% [markdown]
# * Before understanding for loops you should know how range
# function works
# * The range() function is used to generate a sequence of
# numbers, which is commonly used in loops
# * Syntax of range function is simple range(start, stop, steps)
# * you have 3 points from where you want to start, till where
# you want to stop and how many steps you want
# * If you don’t mention start point the default value will be 0 .
# if you don’t mention the steps the default steps will be 1.
# * you have to mention the stop point otherwise the range
# function will not work.

# %%
for i in range(5):
    print(i)

# %%
for x in range(0,21,2):
    print(x)

# %%
for m in range(11,1,-1):
    print(m)

# %% [markdown]
# ##### Use for when:
#
# * You know what you’re looping over
# * The data already exists
# * You want clean, safe iteration
#
# ##### Examples
#
# * Dataset rows
# * Epochs
# * Batches
# * Tokens
# * Characters
#
# ##### 🧠 Where used in ML
#
# * Iterating over rows
# * Iterating over epochs
# * Feature loops (basic level)
#
#  ##### Why this matters in ML
#
# * Large epoch counts
# * Huge loops
# * Memory-sensitive pipelines

# %% [markdown]
# ***

# %% [markdown]
# ### while Loop (Condition-based repetition)
#
# Repeat WHILE a condition is true

# %% [markdown]
# **🔹 Syntax**

# %%
while condition:
    code_block

# %% [markdown]
# **🔹 Example**

# %%
i = 0
while i < 5:
    print(i)
    i += 1

# %%
m = 5
while m < 15:
    print(m)
    m +=1

# %% [markdown]
# #### Loops for strings

# %% [markdown]
# Loops for strings work slightly differently. You can iterate
# through a string in two ways :-

# %% [markdown]
# **Using index values**

# %%
a = "Machine Learning"
for i in range (len(a)):
    print(a[i])

# %% [markdown]
# **Iterating directly over the string**

# %%
for ch in a: 
    print(ch)

# %% [markdown]
# ##### Use while when:
#
# * Loop depends on dynamic state
# * Termination is not count-based
#
# ##### Real ML examples
#
# * Train until loss converges
# * Retry API until success
# * Agent runs until stopped
# * Streaming dat
# *
# ##### 🧠 ML usage
#
# * Training until convergence
# * Early stopping
# * Dynamic stopping conditions

# %% [markdown]
# ***

# %% [markdown]
# ### break (Exit loop immediately)

# %% [markdown]
# The break statement in Python is used to exit a loop
# prematurely when a certain condition is met. Once break is
# encountered, the loop stops immediately, and control moves
# to the next statement after the loop

# %%
for i in range(10):
    if i == 5:
        break
    print(i)

# %% [markdown]
# #### 🧠 Used in:
#
# * Early stopping
# * Search algorithms
# * Error handling

# %% [markdown]
# ***

# %% [markdown]
# ### continue (Skip current iteration)
#
# * The Continue statement skips one of the iteration and rest of
# the iterations will run for understanding lets say you will not
# run the 16th lap but all other lap will be there.
# * Skips the rest of the current iteration and jumps back to the loop start

# %%
for i in range(5):
    if i == 2:
        continue
    print(i)

# %% [markdown]
# #### 🧠 Used in:
#
# * Skipping bad data
# * Ignoring invalid rows
# * Filtering

# %% [markdown]
# ***

# %% [markdown]
# ### pass (Do nothing, intentionally)

# %%
for i in range(3):
    pass
    print(i)

# %% [markdown]
# #### Used when:
#
# * Structure needed
# * Logic to be added later
# * Placeholder in pipelines
# * Abstract pipelines

# %% [markdown]
# ***

# %% [markdown]
# ### Nested Loops (Loop inside loop)

# %%
for i in range(2):
    for j in range(3):
        print(i, j)

# %% [markdown]
# ***

# %% [markdown]
# ### Loop Optimization

# %% [markdown]
# ##### ❌ Bad practice

# %%
for i in range(len(data)):
    print(data[i])

# %% [markdown]
# ##### ✅ Better

# %%
data=[3,55,7,1]
for item in data:
    print(item)

# %% [markdown]
# ##### ❌ ML anti-pattern

# %%
for row in data:
    for col in row:
        process(col)

# %% [markdown]
# **ML best practice**
#
# * Use vectorization (NumPy)
# * Batch processing
# * Avoid Python loops when possible

# %% [markdown]
# ***

# %% [markdown]
# ### ML & Data Preprocessing Use Cases

# %% [markdown]
# #### 🔹 Epoch loop

# %%
for epoch in range(epochs):
    train()

# %% [markdown]
# #### 🔹 Batch processing

# %%
for batch in batches:
    update_weights(batch)

# %% [markdown]
# #### 🔹 Data cleaning

# %%
for value in data:
    if value is None:
        continue
    clean(value)

# %% [markdown]
# #### 🔹 Early stopping

# %%
while loss > threshold:
    train()

# %% [markdown]
# ***

# %% [markdown]
# ## DEEPER TOPICS RELATED TO LOOPS
# ### else with loops

# %%
for i in range(5):
    if i == 10:
        break
else:
    print("Loop finished without break")

# %% [markdown]
# #### 🧠 Meaning:
#
# * else runs only if loop completes normally
# * Does NOT run if break happens
#
# #### Used in:
#
# * search algorithms
# * validation logic

# %% [markdown]
# ***

# %% [markdown]
# ### enumerate() — index + value safely

# %%
data = ["a", "b", "c"]

for index, value in enumerate(data):
    print(index, value)

# %% [markdown]
# ***

# %% [markdown]
# ### zip() — parallel looping

# %%
names = ["A", "B"]
scores = [90, 80]

for n, s in zip(names, scores):
    print(n, s)

# %% [markdown]
# #### Used heavily in:
#
# * feature-label pairing
# * datasets

# %% [markdown]
# ***

# %% [markdown]
# ### List Comprehensions (LOOPS IN ONE LINE)

# %%
squares = [x*x for x in range(5)]
print(squares)

# %%
#Equivalent to:

squares = []
for x in range(5):
    squares.append(x*x)
    print(squares)

# %% [markdown]
# ##### Used everywhere in:
#
# * preprocessing
# * feature creation

# %% [markdown]
# ***

# %% [markdown]
# ### Generator Expressions (MEMORY EFFICIENT)

# %%
gen = (x*x for x in range(10))
print(gen)

# %% [markdown]
# Does not compute all at once.
#
# ##### Used in:
#
# * large datasets
# * streaming data

# %% [markdown]
# ### PRACTICE QUESTIONS

# %%
for i in range(3):
    if i == 1:
        continue
    print(i)

# %%
i = 0
while i < 3:
    print(i)
    i += 1

# %%
#Q. Accept an integer and Print hello world n times
n= int(input("Enter a Number"))
for i in range(n):
    print("Hello world ")

# %%
#Q. Print natural number up to n
n= int(input("Enter a Number"))
for i in range(1,n+1):
    print(i)

# %%
#Q. Reverse for loop. Print n to 1 
n= int(input("Enter a Number"))
for i in range(n,0,-1):
    print(i)

# %%
#Q. Take a number as input and print its table 
num= int(input("Enter a Number"))
for i in range(1,11,):
    print(f"{num} * {i} = {num*i}")

# %%
#Q. Sum up to n terms 
n= int(input("Enter a Number")) 
sum = 0
for i in range(n,0,-1):
    sum =sum + i
print(f" Sum of {n} are : {sum}")

# %%
#Q. Factorial of a number 
n= int(input("Enter a Number")) 
fact = 1
for i in range(1,n+1):
    fact =fact* i
print(f" Factorial of {n} is : {fact}")

# %%
#Q. Print the sum of all even & odd numbers in a range separately
even=0
odd =0
for i in range(1,10):
    if i%2==0:
        even +=i
    else:
        odd +=i
print(f"Sum of all Even and Odd Nos are {even}, {odd}")

# %%
#Q. Print all the factors of a number
n=int(input("Enter a Number"))
for i in range(1,n+1):
    if n%i ==0: 
        print(i)

# %%
#Q. Accept a number and check if it a perfect number or not. A number whose sum of factors is equal to the number itself 
#Ex -  6 = 1, 2, 3 =6 
n=int(input("Enter a Number to check if it a perfect number or not"))
sum=0
for i in range(1,n):
    if n%i ==0:
        sum += i
if sum == n:
    print("Perfect number ")
else:
    print("not a Perfect number ")

# %%
#Q. Check wether the number is prime or not
n=int(input("Enter a Number to check if it a perfect number or not"))
count=0
for i in range(1,n+1):
    if n%i ==0:
        count += 1
if count == 2:
    print("Prime no. ")
else:
    print("not a Prime no. ")

# %%
#Q. Reverse a string without using in build functions
name="kamran kausher"
for i in range(len(name)-1,-1,-1): 
    print(name[i])

# %%
#Q. Check string is Pallindrome or not
name=input("Enter a string")
rev=""
for i in range(len(name)-1,-1,-1): 
    rev =rev + name[i]
if rev == name:
    print("Palindrome")
else:
    print("Not a Palindrome")

# %%
#Q. Count all letters, digits, and special symbols from a given string 
#Given: str1 = "P@#yn26at^&i5ve" 
#Expected Outcome: Total counts of chars, digits, and symbols 
#Chars = 8 
#Digits = 3 
#Symbol = 4

a = "jdhdbd938374jfj%^()%$#kjf3747"
dig=0
char=0
espcl=0
for i in a:
    if i.isdigit():
        dig +=1 
    elif i.isalpha(): 
        char += 1 
    else:
        espcl +=1
print(f"total chars are {char}\n total digits are {dig}\n total symbol are {espcl}")

# %%
 #Q. Separate each digit of a number and print it on the new line
num = int(input("Enter a number"))
while num > 0:
    print(num % 10)
    num = num // 10

# %%
#Q. Accept a number and print its reverse
num = int(input("Enter a number"))
rev = 0
while num > 0:
    rev =( rev * 10 + num % 10)
    num = num // 10
print(rev)

# %%
#Q. Accept a number and check if it is a pallindromic number (If number and its reverse are equal)
num = int(input("Enter a number"))
copy=num
rev = 0
while num > 0:
    rev =( rev * 10 + num % 10)
    num = num // 10

if rev == copy: 
    print("Palindrome")
else:
    print("Not a Palindrome")

# %%
#Q. Create a random number guessing game with python.

# %%
#Q1 Write a program to print numbers from 1 to 10 using a loop.
for i in range(1,11):
    print(i)

# %%
#Q2 Write a program to print all even numbers between 1 and 20.
for x in range(2,21,2):
    print(x)

# %%
#Q3 Write a program to print each character of a string using a loop.
str="KAMRAN KAUSHER"
for i in str:
    print(i)

# %%
#Q4 Write a program to calculate the sum of elements in a list.
l=[2,4,6,8]
total = 0
for n in l:
    total += n
print(total)

# %%
#Q5 Write a program to count how many elements are present in a list without using len().
nums = [10, 22 ,20, 30,45]
count = 0
for _ in nums:
    count += 1
print(count)

# %%
#Q6 Write a program to print numbers from 10 to 1 using a loop.
for i in range (10,0,-1):
    print(i)

# %%
#Q7 Write a program to stop printing numbers when the number 5 is encountered.
for x in range(1,10):
    if x == 5:
        break
    print(x)

# %%
#Q8 Write a program to skip printing the number 3 while looping from 1 to 5.
for n in range(1,6):
    if n == 3:
        continue
    print(n)

# %%
#Q9 Write a program to check whether a list is empty using a loop-based approach.
list =[0]
for x in list:
    if x:
        print("Not empty")
    else:
        print("List is empty")

# %%
#Q10 Write a program to print the multiplication table of a given number.
num = 5
for i in range(1, 11):
    print(num * i)

# %%
#Q11 Write a program to print all elements of a list along with their index.
l=["cat", 56,-3,0,"bat", "Ai",10]
for index, value in enumerate(l):
    print(index, value)

# %%
#Q12 Write a program to print numbers from 1 to 100 but stop when the number becomes greater than 50.
for i in range(1,101):
    if i>50:
        break
    print(i)

# %%
#Q13 Write a program to print only positive numbers from a list.
list =[2,-12,45,66,10,-33,1,9,28,0,-2]
for x in list:
    if x>=0:
        print(x)

# %%
#Q14 Write a program to print all odd numbers from a given list.
for x in list:
    if x%2 !=0:
        print(x)

# %%
#Q15 Write a program to print numbers from 1 to 10 except multiples of 3.
for x in range(1,11):
    if x % 3 != 0:
        pass
        print(x)

# %%
#Q16 Write a program to check whether a number exists in a list.
num= int(input("Enter a number"))
list=[2,4,55,78,0,12]
for x in list:
    if x == num:
        print(f"{num} exit in this list")

# %%
#Q17 Write a program to iterate through a list of names and print them one by one.
name=["MACHINE LEARNING", "AI", "DEEP LEARNING"]
for i in name:
    print(i)

# %%
#Q18 Write a program to count how many vowels are present in a string.
s = "education"
count = 0
for ch in s:
    if ch in "aeiou":
        count += 1
print(count)

# %%
#Q19 Write a program to print numbers using a while loop instead of a for loop.
i = 0
while i < 6:
    print(i)
    i += 1

# %%
#Q20 Write a program that runs a loop but does nothing inside it (use pass).
for i in range(0,20,4):
    pass
    print()

# %%
#Q21 Write a program to find the first number divisible by both 3 and 5 between 1 and 100 and stop once found.
for num in range(1,101):
    if num % 3 == 0 and num % 5 == 0:
        print(num)
        break

# %%
#Q22 Write a program to check whether a given number is prime using loops.
num = 17
is_prime = True

for i in range(2, num):
    if num % i == 0:
        is_prime = False
        break

if is_prime and num > 1:
    print("Prime")
else:
    print("Not Prime")

# %%
#Q23  Write a program to print all prime numbers between 1 and 50.
for num in range(2, 51):
    for i in range(2, num):
        if num % i == 0:
            break
    else:
        print(num)

# %%
#Q24 Write a program to search for an element in a list and print “Found” or “Not Found” using for–else.
nums = [1, 2, 3]
target = 5

for n in nums:
    if n == target:
        print("Found")
        break
else:
    print("Not Found")

# %%
#Q25 Write a program to pair two lists (names and scores) and print them together.
names = ["A", "B"]
scores = [90, 80]

for n, s in zip(names, scores):
    print(n, s)

# %%
#Q26 Write a program to print indexes and values of a list using enumerate().
data = ["x", "y", "z"]
for i, v in enumerate(data):
    print(i, v)

# %%
#Q27 Write a program to create a new list containing squares of all numbers from 1 to 10 using a loop.
squares = []
for i in range(1, 11):
    squares.append(i * i)
print(squares)

# %%
#Q28 Write a program to filter out negative numbers from a list.
list_1 = [0,-1,3,55,-12,6,10,-26,-66]
for x in list_1:
    if x >= 0:
        pass
        print(x)

# %%
#Q29 Write a program to stop a loop when a None value is encountered in a dataset.
data =[3,5,22,"kk", None , True,2]
for value in data:
    if value == None:
        break
        print("None value encountere")

# %%
#Q30 Write a program to count how many numbers are greater than 50 in a list.
list_2 =[2,12,495,6,100,43,1,9,728,550,-2]
count = 0
for _ in list_2:
    if _ >50:
        count += 1
print(count)

# %%
#Q31 Write a program to simulate an ML training loop that runs for a fixed number of epochs.

# %%
#Q32 Write a program to skip invalid (None) values while processing data.
data=[2,44,0,34,"kk","cat",45,0,5]
for x in data:
    if x == False:
        continue
    print(x)

# %%
#Q33 Write a program to flatten a nested list using nested loops.

# %%
#Q34 Write a program to generate a list of even numbers using list comprehension.

# %%
#Q35 Write a program to iterate over two lists together and stop when the shorter list ends.

# %%
#Q36 Write a program to detect whether a number is prime using for–else logic.

# %%
#Q37 Write a program to stop ML training early when loss falls below a threshold.

# %%
#Q38 Write a program to compare two lists element-by-element using zip().

# %%
#Q39  Write a program to generate squares of numbers using a generator instead of a list.

# %%
#Q40 Write a program to process a very large dataset efficiently using generators.

# %%
#Q41 Write a program to count word frequencies in a sentence using loops.

# %%
#Q42 Write a program to remove duplicate values from a list using loops.

# %%
#Q43 Write a program to simulate batch processing in ML using loops.

# %%
#Q44 Write a program to validate data before training an ML model using loops.

# %%
#Q45 Write a program to detect infinite loop conditions and prevent them logically.

# %%
#Q46 Write a program to replace nested loops with list comprehensions where possible.

# %%
#Q47 Write a program to search for multiple target values in a list efficiently.

# %%
#Q48 Write a program to implement sliding window logic using loops.

# %%
#Q49 Write a program to simulate an autonomous agent decision loop (observe → act → repeat).

# %%
#Q50 Write a program to refactor a slow loop-based solution into a more optimized loop or comprehension.
